# %%
import folium
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# Coordenadas de Bom Jesus
lat = -9.07
long = -44.36

mapa = folium.Map(location=[lat, long], zoom_start=12)
folium.Marker([lat, long], popup="Coordenadas iniciais do município").add_to(mapa)

# %%
###
# Referência: Cadastro Nacional de Estabelecimentos de Saúde (CESNet) - Secretaria de Atenção à Saúde
# DATASUS
###
url = 'https://cnes2.datasus.gov.br/Listar_Mantidas.asp?VCnpj=00749590000150'

# Fazer a solicitação HTTP
response = requests.get(url)
response.encoding = 'latin1'  # Forçar o encoding adequado (tente outros encodings, se necessário)

# Usar BeautifulSoup para analisar o conteúdo
soup = BeautifulSoup(response.text, 'html.parser')

# Encontrar a tabela pelo XPath fornecido
tabela = soup.select_one('table:nth-of-type(3)')  # Seleciona a quarta tabela
df = pd.read_html(str(tabela))[0]
df = df.iloc[2:].reset_index(drop=True)
df.columns = ["CNES", "Nome_Fantasia", "Razao_Social"]
df = df.iloc[:-1].reset_index(drop=True)
# Out:
# C:\Users\isaac\AppData\Local\Temp\ipykernel_5836\3528896388.py:16: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(tabela))[0]

# %%
df.head(10)
# Out:
#       CNES                                      Nome_Fantasia  \
# 0  9724311      UBS JOSE MARCOS DOS SANTOS MEDRADO MARIQUINHO
# 1  7538715                      CENTRO INTEGRADO DE SAUDE CIS
# 2  3651878                                  CAPS DE BOM JESUS
# 3  2367599                                        PS DE MATAO
# 4  2367602                      UBS JOSE NUNES DE VASCONCELOS
# 5  2367610                             UBS DR RAIMUNDO SANTOS
# 6  6413722                      UBS JAQUELINE ROSAL NEGREIROS
# 7  9065849  UNID BASICA DE SAUDE RAIMUNDO NONATO NUNES DA ...
# 8  0066370                                UBS ITANE FRANCISCO
# 9  2367629                                   PS DE MUCAMBINHO
#
#                                   Razao_Social
# 0                             SMS DE BOM JESUS
# 1   MUNICIPIO DE BOM JESUS SECRETARIA DE SAUDE
# 2                         BOM JESUS PREFEITURA
# 3                             SMS DE BOM JESUS
# 4                             SMS DE BOM JESUS
# 5                             SMS DE BOM JESUS
# 6  SECRETARIMA MUNICIPAL DE SAUDE DE BOM JESUS
# 7                             SMS DE BOM JESUS
# 8                             SMS DE BOM JESUS
# 9                             SMS DE BOM JESUS

# %%
coordenadas = [
    "-9.065192434847171, -44.34976568682047",
    "-9.061766112748762, -44.36219261696824",
    "-9.073839399558324, -44.35566434395315",
    "-,-",
    "-9.211060923576369, -44.44199478879008",
    "-9.076144451430212, -44.363374532311354",
    "-9.062307282579939, -44.36549564395349",
    "-9.070740503071892, -44.36690217463968",
    "-9.079804186253673, -44.37062237649033",
    "-9.36124849065337, -44.529189514411165",
    "-9.072027066224818, -44.362389805326046",
    "-9.072835461157972, -44.35117129792385",
    "-9.169750710537066, -44.40194730833758",
    "-9.081786560010245, -44.35841802464951",
    "-,-",
    "-8.97667161044772, -44.316290752252456",
    "-,-",
    "-,-",
    "-,-",
    "-,-",
    "-9.062179443860284, -44.357727411514965",
    "-9.072316387887032, -44.360934545803715",
    "-9.056200654794198, -44.37716806114741"
]

# %%
df["coordenadas"] = coordenadas
df.head()
# Out:
#       CNES                                  Nome_Fantasia  \
# 0  9724311  UBS JOSE MARCOS DOS SANTOS MEDRADO MARIQUINHO
# 1  7538715                  CENTRO INTEGRADO DE SAUDE CIS
# 2  3651878                              CAPS DE BOM JESUS
# 3  2367599                                    PS DE MATAO
# 4  2367602                  UBS JOSE NUNES DE VASCONCELOS
#
#                                  Razao_Social  \
# 0                            SMS DE BOM JESUS
# 1  MUNICIPIO DE BOM JESUS SECRETARIA DE SAUDE
# 2                        BOM JESUS PREFEITURA
# 3                            SMS DE BOM JESUS
# 4                            SMS DE BOM JESUS
#
#                               coordenadas
# 0  -9.065192434847171, -44.34976568682047
# 1  -9.061766112748762, -44.36219261696824
# 2  -9.073839399558324, -44.35566434395315
# 3                                     -,-
# 4  -9.211060923576369, -44.44199478879008

# %%
df_UBS = df[df["coordenadas"] != "-,-"].copy()

# %%
df_UBS[["Lat", "Long"]] = df_UBS["coordenadas"].str.split(", ", expand=True).astype(float)

# %%
mapa = folium.Map(location=[df_UBS["Lat"].iloc[0], df_UBS["Long"].iloc[0]], zoom_start=12)

for _, row in df_UBS.iterrows():
    folium.Marker(
        location=[row["Lat"], row["Long"]],
        popup=f"CNES: {row['CNES']}<br>Nome Fantasia: {row['Nome_Fantasia']}<br>Razão Social: {row['Razao_Social']}",
    ).add_to(mapa)

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de260c39ea7818ea5a6a2213f62491aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de260c39ea7818ea5a6a2213f62491aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de260c39ea7818ea5a6a2213f62491aa = L.map(
#                 &quot;map_de260c39ea7818ea5a6a2213f62491aa&quot;,
#                 {
#                     center: [-9.065192434847171, -44.34976568682047],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_46a5460b7876d431fa215cd68856388d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_46a5460b7876d431fa215cd68856388d.addTo(map_de260c39ea7818ea5a6a2213f62491aa);
#
#
#             var marker_d234edf7e51a89962f75b228a0e80aa7 = L.marker(
#                 [-9.065192434847171, -44.34976568682047],
#                 {
# }
#             ).addTo(map_de260c39ea7818ea5a6a2213f62491aa);
#
#
#         var popup_40026dd09bcbe9a232edb5b2bd061a31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ad7093b520f75e1f99fe3457b86bde7 = $(`&lt;div id=&quot;html_7ad7093b520f75e1f99fe3457b86bde7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CNES: 9724311&lt;br&gt;Nome Fantasia: UBS JOSE MARCOS DOS SANTOS MEDRADO MARIQUINHO&lt;br&gt;Razão Social: SMS DE BOM JESUS&lt;/div&gt;`)[0];
#                 popup_40026dd09bcbe9a232edb5b2bd061a31.setContent(html_7ad7093b520f75e1f99fe3457b86bde7);
#
#
#
#         marker_d234edf7e51a89962f75b228a0e80aa7.bindPopup(popup_40026dd09bcbe9a232edb5b2bd061a31)
#         ;
#
#
#
#
#             var marker_0c66f4549d2dd52762b90aef3152f8df = L.marker(
#                 [-9.061766112748762, -44.36219261696824],
#                 {
# }
#             ).addTo(map_de260c39ea7818ea5a6a2213f62491aa);
#
#
#         var popup_ef6f25a229b6ad262e00b996ea6fbf43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32df948a28d403f1d129e805e620dffb = $(`&lt;div id=&quot;html_32df948a28d403f1d129e805e620dffb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CNES: 7538715&lt;br&gt;Nome Fantasia: CENTRO INTEGRADO DE SAUDE CIS&lt;br&gt;Razão Social: MUNICIPIO DE BOM JESUS SECRETARIA DE SAUDE&lt;/div&gt;`)[0];
#                 popup_ef6f25a229b6ad262e00b996ea6fbf43.setContent(html_32df948a28d403f1d129e805e620dffb);
#
#
#
#         marker_0c66f4549d2dd52762b90aef3152f8df.bindPopup(popup_ef6f25a229b6ad262e00b996ea6fbf43)
#         ;
#
#
#
#
#             var marker_9f9e02f802743d37f71c0b095097bef0 = L.marker(
#                 [-9.073839399558324, -44.35566434395315],
#                 {
# }
#             ).addTo(map_de260c39ea7818ea5a6a2213f62491aa);
#
#
#         var popup_215677f2ae963e4c2553141f04192ef8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c1adbeb4d33573311758eba55d97e5d = $(`&lt;div id=&quot;html_7c1adbeb4d33573311758eba55d97e5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CNES: 3651878&lt;br&gt;Nome Fantasia: CAPS DE BOM JESUS&lt;br&gt;Razão Social: BOM JESUS PREFEITURA&lt;/div&gt;`)[0];
#                 popup_215677f2ae963e4c2553141f04192ef8.setContent(html_7c1adbeb4d33573311758eba55d97e5d);
#
#
#
#         marker_9f9e02f802743d37f71c0b095097bef0.bindPopup(popup_215677f2ae963e4c2553141f04192ef8)
#         ;
#
#
#
#
#             var marker_091058392af857b50dbcf314f5369cd7 = L.marker(
#                 [-9.211060923576369, -44.44199478879008],
#                 {
# }
#             ).addTo(map_de260c39ea7818ea5a6a2213f62491aa);
#
#
#         var popup_01f9042e85c1087c04005c16c2cd8a90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b583a3da5f08a6fdd1f103ae9f16e7d = $(`&lt;div id=&quot;html_9b583a3da5f08a6fdd1f103ae9f16e7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CNES: 2367602&lt;br&gt;Nome Fantasia: UBS JOSE NUNES DE VASCONCELOS&lt;br&gt;Razão Social: SMS DE BOM JESUS&lt;/div&gt;`)[0];
#                 popup_01f9042e85c1087c04005c16c2cd8a90.setContent(html_9b583a3da5f08a6fdd1f103ae9f16e7d);
#
#
#
#         marker_091058392af857b50dbcf314f5369cd7.bindPopup(popup_01f9042e85c1087c04005c16c2cd8a90)
#         ;
#
#
#
#
#             var marker_d408832cf61ffa08cfa07890dbbd78eb = L.marker(
#                 [-9.076144451430212, -44.363374532311354],
#                 {
# }
#             ).addTo(map_de260c39ea7818ea5a6a2213f62491aa);
#
#
#         var popup_b67df9f306dba1e7e5eaec8f3cc96bbd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5cdba6f2d1ffa60ad56d8e85e1023bed = $(`&lt;di
